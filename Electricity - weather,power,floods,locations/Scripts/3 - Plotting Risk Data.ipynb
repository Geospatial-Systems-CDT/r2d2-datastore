# %%
# Plots the National Power Outage data on a map in the North East. 

# Uses google maps data, national flood watch, weather data and power outage data.

# Needs API keys of:
# api_key = 'GOOGLE_MAPS_API_KEY' # https://developers.google.com/maps/documentation/javascript/get-api-key
# api_key = "WEATHER_API_KEY"     # https://www.weatherapi.com/

import folium
import requests
import pandas as pd

# %% [markdown]
# Mapping Durham

# %%
import json

def mapify_durham(map = None):
    """ creates a map of Durham"""
    import folium
    with open('durham.geojson') as f:
        durham = json.load(f)
    list_durham = durham["geometry"]["coordinates"][0][0]

    durham_geom = [[i[1], i[0]] for i in list_durham]
    centre_coods = [54.7753, -1.5849]
    if map:
        map = map
    else:
        map = folium.Map(location=centre_coods, zoom_start=10) #New Castle
    folium.Polygon(
        locations = durham_geom,
        color='blue', 
        fill=True, 
        fill_color='blue',
        fill_opacity=0.5
    ).add_to(map)
    map
    return map
mapify_durham() # Function call
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56a0d2603de219d4435b7b0fce1274fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56a0d2603de219d4435b7b0fce1274fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56a0d2603de219d4435b7b0fce1274fc = L.map(
#                 &quot;map_56a0d2603de219d4435b7b0fce1274fc&quot;,
#                 {
#                     center: [54.7753, -1.5849],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc910b2f3f167d6d15139032ac987284 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_56a0d2603de219d4435b7b0fce1274fc);
#
#
#             var polygon_fd1649cd89c7a22e6a1438cb80fdedd9 = L.polygon(
#                 [[54.882037, -1.559411], [54.881519, -1.560617], [54.881388, -1.560977], [54.881382, -1.561117], [54.881319, -1.56116], [54.881254, -1.561168], [54.881196, -1.561237], [54.88084, -1.562011], [54.880849, -1.56238], [54.880814, -1.562998], [54.880778, -1.563896], [54.88072, -1.565806], [54.880683, -1.566578], [54.880632, -1.566878], [54.880472, -1.56807], [54.880355, -1.568556], [54.880164, -1.568967], [54.880064, -1.569424], [54.879753, -1.570168], [54.879464, -1.571022], [54.879372, -1.57148], [54.879302, -1.571897], [54.879248, -1.572401], [54.879124, -1.573812], [54.879048, -1.574856], [54.878954, -1.575912], [54.87865, -1.575904], [54.878298, -1.575877], [54.878215, -1.576805], [54.877848, -1.578854], [54.87777, -1.579909], [54.878166, -1.580002], [54.878811, -1.580108], [54.879549, -1.580318], [54.88047, -1.580566], [54.881342, -1.580784], [54.881996, -1.580966], [54.88489, -1.581628], [54.886143, -1.58198], [54.886149, -1.582149], [54.886649, -1.582296], [54.887259, -1.582397], [54.887638, -1.582475], [54.888339, -1.582599], [54.88863, -1.58268], [54.888835, -1.582716], [54.889036, -1.582788], [54.889114, -1.582908], [54.889229, -1.582998], [54.889322, -1.583041], [54.88958, -1.583104], [54.889894, -1.583154], [54.890475, -1.583276], [54.890787, -1.583367], [54.891003, -1.583451], [54.89115, -1.58354], [54.891397, -1.583871], [54.891502, -1.583974], [54.89165, -1.584041], [54.891823, -1.584066], [54.891901, -1.584061], [54.89216, -1.584011], [54.892318, -1.583935], [54.892633, -1.583928], [54.892821, -1.58397], [54.893066, -1.584178], [54.893164, -1.584288], [54.893257, -1.584491], [54.893482, -1.585062], [54.893667, -1.585246], [54.893711, -1.585308], [54.893794, -1.585457], [54.893834, -1.58554], [54.893865, -1.585716], [54.893909, -1.585862], [54.894082, -1.586123], [54.894163, -1.586293], [54.894255, -1.586557], [54.894298, -1.586752], [54.894326, -1.587026], [54.894345, -1.587855], [54.894367, -1.587945], [54.894457, -1.588194], [54.894549, -1.588294], [54.89471, -1.588385], [54.894884, -1.588466], [54.895008, -1.588587], [54.895125, -1.588599], [54.895316, -1.588545], [54.89538, -1.588534], [54.895467, -1.588536], [54.895538, -1.588649], [54.895611, -1.589004], [54.895718, -1.589218], [54.895836, -1.589363], [54.895888, -1.589402], [54.896031, -1.589481], [54.896183, -1.589656], [54.896237, -1.589707], [54.896669, -1.589926], [54.896884, -1.590065], [54.897113, -1.590188], [54.897314, -1.590281], [54.897542, -1.590413], [54.898055, -1.590602], [54.898295, -1.590679], [54.898529, -1.590802], [54.898725, -1.590937], [54.898904, -1.591136], [54.899035, -1.591333], [54.899103, -1.591519], [54.899146, -1.591678], [54.89931, -1.591608], [54.899462, -1.591595], [54.89963, -1.591671], [54.899794, -1.591821], [54.900239, -1.592358], [54.900307, -1.592483], [54.900428, -1.592928], [54.900584, -1.593263], [54.900859, -1.593649], [54.900987, -1.593741], [54.901165, -1.5938], [54.901319, -1.593816], [54.90138, -1.593776], [54.901564, -1.593628], [54.901669, -1.593666], [54.901747, -1.593769], [54.901804, -1.593892], [54.902019, -1.594164], [54.901927, -1.594451], [54.901887, -1.594747], [54.901896, -1.595028], [54.901938, -1.595308], [54.901942, -1.595562], [54.901934, -1.595654], [54.90189, -1.595786], [54.901782, -1.595948], [54.901722, -1.596053], [54.901714, -1.596081], [54.901713, -1.596152], [54.901764, -1.596587], [54.90176, -1.59672], [54.901744, -1.596826], [54.901718, -1.596913], [54.901637, -1.597042], [54.901603, -1.597128], [54.901591, -1.597248], [54.901613, -1.597521], [54.901605, -1.597609], [54.90157, -1.597741], [54.901503, -1.597889], [54.90116, -1.598491], [54.900832, -1.599095], [54.900059, -1.600314], [54.899841, -1.60071], [54.899766, -1.600777], [54.899727, -1.600783], [54.899638, -1.60078], [54.899586, -1.600769], [54.899465, -1.600724], [54.89936, -1.600634], [54.89926, -1.600501], [54.899195, -1.600272], [54.899168, -1.60021], [54.899132, -1.600181], [54.899087, -1.600175], [54.899053,  ...

# %% [markdown]
# Mapping any place using google's API.

# %%
import requests
import folium 
import time
import json

def map_this(query, key, map = None):
    """
    Retrieves a list of queried points in a given location.

    Args:
        query (str): The location to search for hospitals.

    Returns:
        list: A list of hospital names and addresses.
    """
    url = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
    # key = os.environ.get('GOOGLE_MAPS_API_KEY')
    
    if not key:
        raise ValueError('Google Maps API key not found.')

    params = {
        'query': query,
        'key': key,
    }

    stored = []
    while True:
        try:
            res = requests.get(url, params=params)
            res.raise_for_status()
            data = res.json()
            stored.extend(data['results'])
            # hospitals.extend(data)
            if 'next_page_token' in data:
                params['pagetoken'] = data['next_page_token']
                time.sleep(2)
            else:
                break
        except:
            "Error"
    if map:
        map = map
    else:
        map = folium.Map(location=[54.9783, -1.6178], zoom_start=12) #New Castle
    for i in range(0,len(stored)):
        cc = [stored[i]["geometry"]["location"]["lat"], stored[i]["geometry"]["location"]["lng"]]
        folium.Marker(
                    cc
                    , icon=folium.Icon(icon ='fa-h-square', prefix='fa', color='red')
                    , tooltip = [stored[i]["name"]] 
                ).add_to(map)
    return map

hospitals = map_this('all+hospitals+in+north+east+england')

hospitals
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90f1fc3d62a2ff3223e5934a2610837a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90f1fc3d62a2ff3223e5934a2610837a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90f1fc3d62a2ff3223e5934a2610837a = L.map(
#                 &quot;map_90f1fc3d62a2ff3223e5934a2610837a&quot;,
#                 {
#                     center: [54.9783, -1.6178],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5022d6235529875b420328d644a4596a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_90f1fc3d62a2ff3223e5934a2610837a);
#
#
#             var marker_e84a01fd6136949899d185df8a8bcbfe = L.marker(
#                 [55.0254219, -1.467913],
#                 {}
#             ).addTo(map_90f1fc3d62a2ff3223e5934a2610837a);
#
#
#             var icon_fde7c11e58a0f78b795616ff3ffc8c10 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e84a01fd6136949899d185df8a8bcbfe.setIcon(icon_fde7c11e58a0f78b795616ff3ffc8c10);
#
#
#             marker_e84a01fd6136949899d185df8a8bcbfe.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;North Tyneside General Hospital&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9ccd85b982b8d6e7955d5f365e46cb65 = L.marker(
#                 [54.7885266, -1.5933009],
#                 {}
#             ).addTo(map_90f1fc3d62a2ff3223e5934a2610837a);
#
#
#             var icon_432339a0f773b0db18cb22df61b048e9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9ccd85b982b8d6e7955d5f365e46cb65.setIcon(icon_432339a0f773b0db18cb22df61b048e9);
#
#
#             marker_9ccd85b982b8d6e7955d5f365e46cb65.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;University Hospital of North Durham&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d580e59f7bb1726e8443aff34c1b1e34 = L.marker(
#                 [55.18491090000001, -1.7118864],
#                 {}
#             ).addTo(map_90f1fc3d62a2ff3223e5934a2610837a);
#
#
#             var icon_712be4ec05a93313653db0696a934a6e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d580e59f7bb1726e8443aff34c1b1e34.setIcon(icon_712be4ec05a93313653db0696a934a6e);
#
#
#             marker_d580e59f7bb1726e8443aff34c1b1e34.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;Northgate Hospital&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7deb7d46026bba875800d3d3a7164186 = L.marker(
#                 [55.1841261, -1.546962],
#                 {}
#             ).addTo(map_90f1fc3d62a2ff3223e5934a2610837a);
#
#
#             var icon_d5b35f8fc9fcde60f4c447f2ed1869ee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7deb7d46026bba875800d3d3a7164186.setIcon(icon_d5b35f8fc9fcde60f4c447f2ed1869ee);
#
#
#             marker_7deb7d46026bba875800d3d3a7164186.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;Wansbeck General Hospital&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_27c51e58445447eebebf0debfe5af2c8 = L.marker(
#                 [55.00260189999999, -1.593423],
#                 {}
#             ).addTo(map_90f1fc3d62a2ff3223e5934a2610837a);
#
#
#             var icon_1d40c1f5a60a7768a5bbe1d936519c61 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red

# %% [markdown]
# Getting weather/temperature data

# %%
# Adding the weather data

import requests
def map_weather(map = None):
    import folium
    api_key = "WEATHER_API_KEY"
    cities = ['Bishop Auckland', 'Durham', 'Barnard Castle', 'Stanhope', 'Peterlee']
    country = 'UK'
    # Create map centered on Newcastle
    # map = folium.Map(location=[-32.9283, 151.7817], zoom_start=10)
    if map:
        map = map
    else:
        map = folium.Map(location=[54.9783, -1.6178], zoom_start=12)
    
    for city in cities:
        url = f'https://api.weatherapi.com/v1/current.json?key={api_key}&q={city},{country}'
        response = requests.get(url)
        data = response.json()
        temperature = data['current']['temp_c']
        wind_speed = data['current']['wind_kph']
        humidity = data['current']['humidity']
        pressure = data['current']['pressure_mb']
        # folium.Marker(location=get_coordinates(city, country), 
        folium.Marker(location= [data["location"]["lat"], data["location"]["lon"]],
                    popup=f'Temperature: {temperature}°C\nWind speed: {wind_speed} kph\nHumidity: {humidity}%\nPressure: {pressure} mb', 
                    icon=folium.Icon(icon = "fa-solid fa-wind", prefix = "fa", color='blue')).add_to(map)
    return map
cities = ['Bishop Auckland', 'Durham', 'Barnard Castle', 'Stanhope', 'Peterlee']

# %% [markdown]
# Obtaining powercuts from the Northen power grid website, - Color is the nature of the fault.

# %%
import requests
import pandas as pd
import json
import folium

def get_power_cuts(map=None):
    url = 'https://power.northernpowergrid.com/Powercut_API/rest/powercuts/getall'
    response = requests.get(url)
    data = response.json()
    new = pd.DataFrame(data[0:len(data)][0:len(data)])
    # Create a map object
    if map:
        pass
    else:
        map = folium.Map(location=[54.9783, -1.6178], zoom_start=12)
    # # Add a marker for each row of the dataframe
    for index, row in new.iterrows():
        color = ""
        if row['Area']== 'North East':
            if row["NatureOfOutage"] == 'Localised Fault':
                color = 'red'
            elif row["NatureOfOutage"] == 'Large Area Fault':
                color = 'blue'
            else:
                color = 'green'
            folium.Marker([float(row['Lat']), float(row['Lng'])], popup=row[['NatureOfOutage']].to_dict(),
                        icon=folium.Icon(icon = 'fa-solid fa-bolt',prefix = 'fa' , color=color)).add_to(map)
    return map
# # Display the map
get_power_cuts()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6081cbfa3d804c74afc72ca0bab65bd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6081cbfa3d804c74afc72ca0bab65bd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6081cbfa3d804c74afc72ca0bab65bd6 = L.map(
#                 &quot;map_6081cbfa3d804c74afc72ca0bab65bd6&quot;,
#                 {
#                     center: [54.9783, -1.6178],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c01c5c937d75160ed666b527a821d88 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6081cbfa3d804c74afc72ca0bab65bd6);
#
#
#             var marker_74228bd60317a9a7bec9c2c006abeb24 = L.marker(
#                 [54.5718, -1.00433],
#                 {}
#             ).addTo(map_6081cbfa3d804c74afc72ca0bab65bd6);
#
#
#             var icon_3a8ec51ec9d57e8c9022f02d30f1b656 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-bolt&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_74228bd60317a9a7bec9c2c006abeb24.setIcon(icon_3a8ec51ec9d57e8c9022f02d30f1b656);
#
#
#         var popup_3571db4be2c73b11124fc8d02c9f6751 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d85428d07415a70434e7631382496b9f = $(`&lt;div id=&quot;html_d85428d07415a70434e7631382496b9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;{&#x27;NatureOfOutage&#x27;: &#x27;Planned Work on System&#x27;}&lt;/div&gt;`)[0];
#                 popup_3571db4be2c73b11124fc8d02c9f6751.setContent(html_d85428d07415a70434e7631382496b9f);
#
#
#
#         marker_74228bd60317a9a7bec9c2c006abeb24.bindPopup(popup_3571db4be2c73b11124fc8d02c9f6751)
#         ;
#
#
#
#
#             var marker_651742de4cec47be4db03a5e002e25fc = L.marker(
#                 [54.5803, -1.0724],
#                 {}
#             ).addTo(map_6081cbfa3d804c74afc72ca0bab65bd6);
#
#
#             var icon_5ff4c880e16b38a6efbe49633611bf14 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-bolt&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_651742de4cec47be4db03a5e002e25fc.setIcon(icon_5ff4c880e16b38a6efbe49633611bf14);
#
#
#         var popup_010ca32bf390cca1f37f4da951371ad8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e31c3d48d62b69d98f79169b92a88b8 = $(`&lt;div id=&quot;html_1e31c3d48d62b69d98f79169b92a88b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;{&#x27;NatureOfOutage&#x27;: &#x27;Planned Work on System&#x27;}&lt;/div&gt;`)[0];
#                 popup_010ca32bf390cca1f37f4da951371ad8.setContent(html_1e31c3d48d62b69d98f79169b92a88b8);
#
#
#
#         marker_651742de4cec47be4db03a5e002e25fc.bindPopup(popup_010ca32bf390cca1f37f4da951371ad8)
#         ;
#
#
#
#
#             var marker_4255195d7261d4a98344274c464cece1 = L.marker(
#                 [54.5661, -1.02296],
#                 {}
#             ).addTo(map_6081cbfa3d804c74afc72ca0bab65bd6);
#
#
#             var icon_986ec8481e65bc01a53b201c8742a915 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-bolt&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4255195d7261d4a98344274c464cece1.setIcon(icon_986ec8481e65bc01a53b201c8742a915);
#
#
#         var popup_4806f55c068887b98786a073c32b021f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5df827d9df25ef85d5a77e60523b6d50 = $(`&lt;div id=&quot;html_5df827d9df25ef85d5a77e60523b6d50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;{&#x27;NatureOfOutage&#x27;: &#x27;Planned Work on System&#x27;}&lt;/div&gt;`)[0];
#                 popup_4806f55c068887b98786a073c32b021f.setContent(html_5df827d9df25ef85d5a77e60523b6d50);
#
#
#
#         marker_4255195d7261d4a98344274c464cece1.bindPopup(popup_4806f55c068887b98786a073c32b021f)
#         ;
#
#
#
#
#             var marker_983a818574e9bab36c4b2d2b9b0028d6 = L.marker(
#                 [54.5662, -1.02338],
#                 {}
#             ).addTo(map_6081cbfa3d804c74afc72ca0bab65bd6);
#
#
#             var icon_258311b2432ae

# %% [markdown]
# Checking for floods

# %%
def get_floods(floods):
    url = 'https://check-for-flooding.service.gov.uk/api/warnings.geojson'
    response = requests.get(url)
    data = response.json()
    # floods = folium.Map(location=[54.9783, -1.6178], zoom_start=12) #New Castle
    # ADDING MARKERS
    for i in range(0,len(data["features"])):
        cc = [data["features"][i]["geometry"]["coordinates"][1], data["features"][i]["geometry"]["coordinates"][0]]
        if data["features"][i]["properties"]["severity_value"] == 1:
            color = 'green'
        elif data["features"][i]["properties"]["severity_value"] == 2:
            color = 'yellow'
        elif data["features"][i]["properties"]["severity_value"] == 3:
            color = 'orange'
        else:
            color = 'red'
        folium.Marker(
                    cc
                    , icon=folium.Icon(icon = "fa-solid fa-water", prefix = "fa", color=color)
                    , tooltip = [data["features"][i]["properties"]["severity"],data["features"][i]["properties"]["severity_value"], data["features"][i]["properties"]["ta_name"]] 
            
                ).add_to(floods)
    return floods

map = folium.Map(location=[54.9783, -1.6178], zoom_start=12) #New Castle
get_floods(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de17104bec9a8f314e3dcd3d7f03d374 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de17104bec9a8f314e3dcd3d7f03d374&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de17104bec9a8f314e3dcd3d7f03d374 = L.map(
#                 &quot;map_de17104bec9a8f314e3dcd3d7f03d374&quot;,
#                 {
#                     center: [54.9783, -1.6178],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31fd36169ddee068926824f0a65a4c6c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_de17104bec9a8f314e3dcd3d7f03d374);
#
#
#             var marker_9a0fbefd059cd20d652e0d3df685346e = L.marker(
#                 [51.01274269, -2.810165511],
#                 {}
#             ).addTo(map_de17104bec9a8f314e3dcd3d7f03d374);
#
#
#             var icon_da55d5ff0695ff036cc2ea8a2e8e3c7f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-water&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9a0fbefd059cd20d652e0d3df685346e.setIcon(icon_da55d5ff0695ff036cc2ea8a2e8e3c7f);
#
#
#             marker_9a0fbefd059cd20d652e0d3df685346e.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;Warning no longer in force&#x27;, 4, &#x27;River Yeo and River Parrett Moors around Muchelney and Thorney&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_590b75c27ecc60c42dfed6df125bf8aa = L.marker(
#                 [51.652003442, -1.234770616],
#                 {}
#             ).addTo(map_de17104bec9a8f314e3dcd3d7f03d374);
#
#
#             var icon_bcbeea8ec39862994f8dc2627527643e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-water&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_590b75c27ecc60c42dfed6df125bf8aa.setIcon(icon_bcbeea8ec39862994f8dc2627527643e);
#
#
#             marker_590b75c27ecc60c42dfed6df125bf8aa.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;Warning no longer in force&#x27;, 4, &#x27;River Thames for the Abingdon area&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e65f6a94149fcb8a40bcd0ef6ebf72e6 = L.marker(
#                 [51.722753978, -1.481412466],
#                 {}
#             ).addTo(map_de17104bec9a8f314e3dcd3d7f03d374);
#
#
#             var icon_eaeafe6788d5c46d266795dd97c44893 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-water&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e65f6a94149fcb8a40bcd0ef6ebf72e6.setIcon(icon_eaeafe6788d5c46d266795dd97c44893);
#
#
#             marker_e65f6a94149fcb8a40bcd0ef6ebf72e6.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;Warning no longer in force&#x27;, 4, &#x27;River Thames and tributaries from Buscot Wick down to Kings Lock&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a56f232f463be1976045c00e38501249 = L.marker(
#                 [51.662835854, -1.771868064],
#                 {}
#             ).addTo(map_de17104bec9a8f314e3dcd3d7f03d374);
#
#
#             var icon_a2d01dd8fd8a3e697f6287405db4d475 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-water&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a56f232f463be1976045c00e38501249.setIcon(icon_a2d01dd8fd8a3e697f6287405db4d475);
#
#
#             marker_a56f232f463be1976045c00e38501249.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;Warning no longer in force&#x27;, 4, &#x27;River Thames and its small tributaries from Calcutt to Lechlade&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8f9603676d6f304c0db17e273d83fe9d = L.marker(
#                 [52.185139299, -0.539552841],
#                 {}
#             ).addTo(m

# %% [markdown]
# Combining all functions on a single map

# %%
key = "Enter your Google Maps API key here"
mapped_locations = map_this("All hospitals in North East England", key)
mapped_locations 
flood_info = get_floods(mapped_locations)
power_cut_info = get_power_cuts(flood_info)
weather_info = map_weather(power_cut_info)
durham_map = mapify_durham(weather_info)
durham_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a93f9fb914d1b0f2d5d6759f856d5625 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a93f9fb914d1b0f2d5d6759f856d5625&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a93f9fb914d1b0f2d5d6759f856d5625 = L.map(
#                 &quot;map_a93f9fb914d1b0f2d5d6759f856d5625&quot;,
#                 {
#                     center: [54.9783, -1.6178],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72842584dad35fe9996de91a6b8f01ca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a93f9fb914d1b0f2d5d6759f856d5625);
#
#
#             var marker_6d248e601a40967c7a8fb68c1cf5ecda = L.marker(
#                 [55.0254219, -1.467913],
#                 {}
#             ).addTo(map_a93f9fb914d1b0f2d5d6759f856d5625);
#
#
#             var icon_3f926395f78df61b452857f770f81838 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6d248e601a40967c7a8fb68c1cf5ecda.setIcon(icon_3f926395f78df61b452857f770f81838);
#
#
#             marker_6d248e601a40967c7a8fb68c1cf5ecda.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;North Tyneside General Hospital&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2e69aee95a7b3775fba1b403fbaa0e33 = L.marker(
#                 [54.7885266, -1.5933009],
#                 {}
#             ).addTo(map_a93f9fb914d1b0f2d5d6759f856d5625);
#
#
#             var icon_4791746783fbf39354e3f8bcf1200dc5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2e69aee95a7b3775fba1b403fbaa0e33.setIcon(icon_4791746783fbf39354e3f8bcf1200dc5);
#
#
#             marker_2e69aee95a7b3775fba1b403fbaa0e33.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;University Hospital of North Durham&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cc473814d088e93dfc5babbf30887970 = L.marker(
#                 [55.18491090000001, -1.7118864],
#                 {}
#             ).addTo(map_a93f9fb914d1b0f2d5d6759f856d5625);
#
#
#             var icon_0c69d28de9b03dd9b44e7d7ceb3ca2b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cc473814d088e93dfc5babbf30887970.setIcon(icon_0c69d28de9b03dd9b44e7d7ceb3ca2b5);
#
#
#             marker_cc473814d088e93dfc5babbf30887970.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;Northgate Hospital&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aeb97556a22ab746f0a55d757e20295e = L.marker(
#                 [55.1841261, -1.546962],
#                 {}
#             ).addTo(map_a93f9fb914d1b0f2d5d6759f856d5625);
#
#
#             var icon_6066b58e6a3e8fcbf9162c5f32f81513 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_aeb97556a22ab746f0a55d757e20295e.setIcon(icon_6066b58e6a3e8fcbf9162c5f32f81513);
#
#
#             marker_aeb97556a22ab746f0a55d757e20295e.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;Wansbeck General Hospital&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8afd7fc634139c7bf66050f5e4ed6b5a = L.marker(
#                 [55.0279581, -1.5108802],
#                 {}
#             ).addTo(map_a93f9fb914d1b0f2d5d6759f856d5625);
#
#
#             var icon_a450e632a41376e6caaad39b88e6d272 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;

# %% [markdown]
# Demonstrating the opportunity of querying other vulnerable centres.
#
# ### Future work
# Add code that flares/flashes/becomes hotter if the power cut coordinate is near that of a vulnerable centre.
# Extend the code to produce a live heat map of Risk (needs Generalised linear mixed models/ KDEs) using various combined
#
# ####

# %%
mapped_locations = map_this("All old age homes in North East England")
mapped_locations 
flood_info = get_floods(mapped_locations)
power_cut_info = get_power_cuts(flood_info)
weather_info = map_weather(power_cut_info)
durham_map = mapify_durham(weather_info)
durham_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_307544301d042dee3ce07922fb5a30d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_307544301d042dee3ce07922fb5a30d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_307544301d042dee3ce07922fb5a30d9 = L.map(
#                 &quot;map_307544301d042dee3ce07922fb5a30d9&quot;,
#                 {
#                     center: [54.9783, -1.6178],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3bcfdaaa76a6f6826462f5e9046ab03 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_307544301d042dee3ce07922fb5a30d9);
#
#
#             var marker_367db00e653c2fd14778f9101fd78553 = L.marker(
#                 [54.9855847, -1.606369],
#                 {}
#             ).addTo(map_307544301d042dee3ce07922fb5a30d9);
#
#
#             var icon_3a0af9394c15bf4620980a28ff92ef26 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_367db00e653c2fd14778f9101fd78553.setIcon(icon_3a0af9394c15bf4620980a28ff92ef26);
#
#
#             marker_367db00e653c2fd14778f9101fd78553.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;MHA Pilgrims Court - Retirement Apartments&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_367e30d0cb28d0f52eebec4a66f2264a = L.marker(
#                 [54.84210960000001, -1.3349537],
#                 {}
#             ).addTo(map_307544301d042dee3ce07922fb5a30d9);
#
#
#             var icon_43ba7e866f0f4d4f72fe950a523f1670 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_367e30d0cb28d0f52eebec4a66f2264a.setIcon(icon_43ba7e866f0f4d4f72fe950a523f1670);
#
#
#             marker_367e30d0cb28d0f52eebec4a66f2264a.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;Beachcomber Care Home&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_85a68849ab5f59626a3f38f100931193 = L.marker(
#                 [54.92794989999999, -2.0978483],
#                 {}
#             ).addTo(map_307544301d042dee3ce07922fb5a30d9);
#
#
#             var icon_8ca9b49b768bc57413c9259e9a9e693a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_85a68849ab5f59626a3f38f100931193.setIcon(icon_8ca9b49b768bc57413c9259e9a9e693a);
#
#
#             marker_85a68849ab5f59626a3f38f100931193.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;Close House Nursing Home&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_acf884894b9436eed6676622e1b826ac = L.marker(
#                 [55.0276735, -1.6182701],
#                 {}
#             ).addTo(map_307544301d042dee3ce07922fb5a30d9);
#
#
#             var icon_e38878bf7809142d96d2aea5fd6f3a36 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_acf884894b9436eed6676622e1b826ac.setIcon(icon_e38878bf7809142d96d2aea5fd6f3a36);
#
#
#             marker_acf884894b9436eed6676622e1b826ac.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;Melton House&#x27;]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bf12f85366c54cab8fe150614aa8c1fe = L.marker(
#                 [55.18576359999999, -1.5144948],
#                 {}
#             ).addTo(map_307544301d042dee3ce07922fb5a30d9);
#
#
#             var icon_847abe8a65c850ec20e98b3f7a8f1cff = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-h-square&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&
